# %%
from VIIRS.VNP09GA import VNP09GAGranule
from VIIRS.VIIRSDataPool import parse_VIIRS_build

# %%
VNP09GA_C1_filename = "/Users/halverso/Library/CloudStorage/OneDrive-JPL/ECOSTRESS Science Team/VIIRS Collection Comparison/VNP09GA.A2024053.h08v05.001.2024057130512.h5"
VNP09GA_C2_filename = "/Users/halverso/Library/CloudStorage/OneDrive-JPL/ECOSTRESS Science Team/VIIRS Collection Comparison/VNP09GA.A2024053.h08v05.002.2024054095810.h5"

# %%
VNP09GA_C1_granule = VNP09GAGranule(VNP09GA_C1_filename)
VNP09GA_C1_granule.collection
# Out:
# 1

# %%
VNP09GA_C2_granule = VNP09GAGranule(VNP09GA_C2_filename)
VNP09GA_C2_granule.collection
# Out:
# 2

# %%
VNP09GA_C1_granule.red
# Out:
# [2024-06-07 14:30:02 INFO] opening VIIRS file: /Users/halverso/Library/CloudStorage/OneDrive-JPL/ECOSTRESS Science Team/VIIRS Collection Comparison/VNP09GA.A2024053.h08v05.001.2024057130512.h5
# [2024-06-07 14:30:02 INFO] loading HDFEOS/GRIDS/VNP_Grid_500m_2D/Data Fields/SurfReflect_I1_1 at 463.31 m resolution

# %%
VNP09GA_C2_granule.red
# Out:
# [2024-06-07 14:30:03 INFO] opening VIIRS file: /Users/halverso/Library/CloudStorage/OneDrive-JPL/ECOSTRESS Science Team/VIIRS Collection Comparison/VNP09GA.A2024053.h08v05.002.2024054095810.h5
# [2024-06-07 14:30:03 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_500m_2D/Data Fields/SurfReflect_I1_1 at 463.31 m resolution

# %%
VNP09GA_C2_granule.red - VNP09GA_C1_granule.red
# Out:
# [2024-06-07 14:30:04 INFO] opening VIIRS file: /Users/halverso/Library/CloudStorage/OneDrive-JPL/ECOSTRESS Science Team/VIIRS Collection Comparison/VNP09GA.A2024053.h08v05.002.2024054095810.h5
# [2024-06-07 14:30:04 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_500m_2D/Data Fields/SurfReflect_I1_1 at 463.31 m resolution
# [2024-06-07 14:30:05 INFO] opening VIIRS file: /Users/halverso/Library/CloudStorage/OneDrive-JPL/ECOSTRESS Science Team/VIIRS Collection Comparison/VNP09GA.A2024053.h08v05.001.2024057130512.h5
# [2024-06-07 14:30:05 INFO] loading HDFEOS/GRIDS/VNP_Grid_500m_2D/Data Fields/SurfReflect_I1_1 at 463.31 m resolution
