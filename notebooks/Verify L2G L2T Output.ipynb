# %%
from ECOSTRESS.L2_LSTE import L2GLSTE, L2TLSTE
import rasters as rt

# %%
L2G_filename = "/Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2G_LSTE_26055_011_20230209T003243_0710_01.h5"
L2T_filename = "/Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2T_LSTE_26055_011_11SPS_20230209T003243_0710_01.zip"

# %%
L2G_granule = L2GLSTE(L2G_filename)
L2G_granule
# Out:
# L2GLSTE("/Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2G_LSTE_26055_011_20230209T003243_0710_01.h5")

# %%
cloud = L2G_granule.cloud
cloud = rt.where(cloud == 255, 0, cloud)
cloud
# Out:
# [2023-05-12 10:19:31 INFO] started reading HDF-EOS5 dataset: cloud file: /Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2G_LSTE_26055_011_20230209T003243_0710_01.h5
# [2023-05-12 10:19:31 INFO] reading HDFEOS5 raster HDFEOS/GRIDS/ECO_L2G_LSTE_70m/Data Fields/cloud: /Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2G_LSTE_26055_011_20230209T003243_0710_01.h5
# [2023-05-12 10:19:31 INFO] finished reading HDFEOS5 dataset: cloud file: /Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2G_LSTE_26055_011_20230209T003243_0710_01.h5 (0.13)

# %%
water = L2G_granule.water
water = rt.where(water == 255, 0, water)
water
# Out:
# [2023-05-12 10:20:19 INFO] started reading HDF-EOS5 dataset: water file: /Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2G_LSTE_26055_011_20230209T003243_0710_01.h5
# [2023-05-12 10:20:19 INFO] reading HDFEOS5 raster HDFEOS/GRIDS/ECO_L2G_LSTE_70m/Data Fields/water: /Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2G_LSTE_26055_011_20230209T003243_0710_01.h5
# [2023-05-12 10:20:19 INFO] finished reading HDFEOS5 dataset: water file: /Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2G_LSTE_26055_011_20230209T003243_0710_01.h5 (0.13)

# %%
L2T_granule = L2TLSTE(L2T_filename)
L2T_granule
# Out:
# L2TLSTE("/Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2T_LSTE_26055_011_11SPS_20230209T003243_0710_01.zip")

# %%
L2T_granule.cloud
# Out:
# [2023-05-12 10:20:59 INFO] started reading L2T_LSTE cloud: zip:///Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2T_LSTE_26055_011_11SPS_20230209T003243_0710_01.zip!/ECOv002_L2T_LSTE_26055_011_11SPS_20230209T003243_0710_01/ECOv002_L2T_LSTE_26055_011_11SPS_20230209T003243_0710_01_cloud.tif
# [2023-05-12 10:20:59 INFO] finished reading L2T_LSTE cloud (0.02s)

# %%
L2T_granule.water
# Out:
# [2023-05-12 10:22:36 INFO] started reading L2T_LSTE water: zip:///Users/halverso/data/ECOSTRESS_test_runs/26055_011/L1_L2_RAD_LSTE_output/ECOv002_L2T_LSTE_26055_011_11SPS_20230209T003243_0710_01.zip!/ECOv002_L2T_LSTE_26055_011_11SPS_20230209T003243_0710_01/ECOv002_L2T_LSTE_26055_011_11SPS_20230209T003243_0710_01_water.tif
# [2023-05-12 10:22:36 INFO] finished reading L2T_LSTE water (0.01s)
