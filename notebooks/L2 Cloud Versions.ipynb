# %%
from ECOSTRESS.L2_CLOUD import L2CLOUD
from ECOSTRESS.L2_LSTE import L2LSTE

# %%
L2_CLOUD_6_filename = "/Users/halverso/data/ECOv002_cloud/ECOSTRESS_L2_CLOUD_06108_006_20190803T203332_0601_02.h5"
L2_CLOUD_7_filename = "/Users/halverso/data/ECOv002_cloud/ECOSTRESS_L2_CLOUD_06108_006_20190803T203332_9700_90.h5"
L2_LSTE_6_filename = "/Users/halverso/data/ECOv002_cloud/ECOSTRESS_L2_LSTE_06108_006_20190803T203332_0601_02.h5"
L2_LSTE_7_filename = "/Users/halverso/data/ECOv002_cloud/ECOSTRESS_L2_LSTE_06108_006_20190803T203332_9700_90.h5"

# %%
L2_CLOUD_6_granule = L2CLOUD.open(L2_CLOUD_filename=L2_CLOUD_6_filename)
L2_CLOUD_6_granule
# Out:
# L2_CLOUD("/Users/halverso/data/ECOv002_cloud/ECOSTRESS_L2_CLOUD_06108_006_20190803T203332_0601_02.h5")

# %%
L2_CLOUD_6_granule.build
# Out:
# '0601'

# %%
type(L2_CLOUD_6_granule)
# Out:
# ECOSTRESS.L2_CLOUD.ECOv001L2CLOUD

# %%
L2_CLOUD_7_granule = L2CLOUD.open(L2_CLOUD_filename=L2_CLOUD_7_filename)
L2_CLOUD_6_granule
L2_CLOUD_7_granule
# Out:
# L2_CLOUD("/Users/halverso/data/ECOv002_cloud/ECOSTRESS_L2_CLOUD_06108_006_20190803T203332_9700_90.h5")

# %%
L2_CLOUD_7_granule.build
# Out:
# '9700'

# %%
type(L2_CLOUD_7_granule)
# Out:
# ECOSTRESS.L2_CLOUD.ECOv002L2CLOUD

# %%
L2_CLOUD_6_granule.cloud

# %%
L2_CLOUD_7_granule.cloud

# %%
L2_CLOUD_7_granule.Cloud_test_1

# %%
L2_CLOUD_7_granule.Cloud_test_2

# %%
L2_CLOUD_6_granule.water
