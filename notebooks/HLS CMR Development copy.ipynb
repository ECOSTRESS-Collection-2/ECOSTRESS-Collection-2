# %%
from HLS import HLS2CMRSTAC, HLS2CMR, HLS_CMR_query, S30_CMR_query, S30_CONCEPT, CMR_query, CMR_query_URLs
from datetime import datetime, timedelta, time, date
import pandas as pd
from dateutil import parser
from daterange import date_range

# %%
SENTINEL_REPEAT_DAYS = 5
LANDSAT_REPEAT_DAYS = 16
GIVEUP_DAYS = 10
giveup_date = datetime.utcnow().date() - timedelta(days=GIVEUP_DAYS)
giveup_date
# Out:
# datetime.date(2022, 11, 1)

# %%
tile = "11SPS"
start_date = parser.parse("2022-11-01").date()
end_date = parser.parse("2022-12-01").date()
working_directory = "~/data/HLS2CMR_testing"

# %%
CMR = HLS2CMR(working_directory=working_directory)
CMR
# Out:
# [2022-11-11 15:20:59 INFO] HLS 2.0 CMR URL: https://cmr.earthdata.nasa.gov/search
# [2022-11-11 15:20:59 INFO] HLS 2.0 working directory: /Users/halverso/data/HLS2CMR_testing
# [2022-11-11 15:20:59 INFO] HLS 2.0 download directory: /Users/halverso/data/HLS2CMR_testing/HLS2_download
# [2022-11-11 15:20:59 INFO] HLS 2.0 products directory: /Users/halverso/data/HLS2CMR_testing/HLS2_products
# [2022-11-11 15:20:59 INFO] checking URL: https://cmr.earthdata.nasa.gov/search
# [2022-11-11 15:20:59 INFO] remote verified with status 200 in 0.38 seconds: https://cmr.earthdata.nasa.gov/search
# HLS2CMR(
# 	working_directory="/Users/halverso/data/HLS2CMR_testing",
# 	download_directory="/Users/halverso/data/HLS2CMR_testing/HLS2_download",
# 	products_directory="/Users/halverso/data/HLS2CMR_testing/HLS2_products",
# 	remote="https://cmr.earthdata.nasa.gov/search"
# )

# %%
listing = CMR.listing(
    tile=tile,
    start_UTC=start_date,
    end_UTC=end_date
)

listing
# Out:
# [2022-11-11 15:20:59 INFO] started listing available HLS2 granules at tile 11SPS from 2022-11-01 to 2022-12-01
# [2022-11-11 15:21:02 INFO] searching HLSS30.v2.0, HLSL30.v2.0 at 11SPS from 2022-10-16 to 2022-12-01
# [2022-11-11 15:21:02 INFO] CMR API query for HLS Landsat S30 at tile 11SPS from 2022-10-16 to 2022-12-01
# [2022-11-11 15:21:02 INFO] CMR API query for concept ID C2021957295-LPCLOUD at tile 11SPS from 2022-10-16 to 2022-12-01 with URL: https://cmr.earthdata.nasa.gov/search/granules.json?concept_id=C2021957295-LPCLOUD&temporal=2022-10-16T00:00:00Z/2022-12-01T23:59:59Z&page_size=2000&producer_granule_id=*.T11SPS.*&options[producer_granule_id][pattern]=true
# [2022-11-11 15:21:02 INFO] CMR API query for concept ID C2021957295-LPCLOUD at tile 11SPS from 2022-10-16 to 2022-12-01 included 540 URLs
# ...

# %%
listing = CMR.listing(
    tile=tile,
    start_UTC=start_date,
    end_UTC=end_date
)

listing
# Out:
#       date_UTC   tile                            sentinel  \
# 0   2022-11-01  11SPS  HLS.S30.T11SPS.2022305T182521.v2.0
# 1   2022-11-02  11SPS                                 NaN
# 2   2022-11-03  11SPS  HLS.S30.T11SPS.2022307T181519.v2.0
# 3   2022-11-04  11SPS                                 NaN
# 4   2022-11-05  11SPS                                 NaN
# 5   2022-11-06  11SPS  HLS.S30.T11SPS.2022310T182539.v2.0
# 6   2022-11-07  11SPS                                 NaN
# 7   2022-11-08  11SPS  HLS.S30.T11SPS.2022312T181551.v2.0
# 8   2022-11-09  11SPS                                 NaN
# 9   2022-11-10  11SPS                                 NaN
# 10  2022-11-11  11SPS                             missing
# 11  2022-11-12  11SPS                                 NaN
# 12  2022-11-13  11SPS                             missing
# 13  2022-11-14  11SPS                                 NaN
# 14  2022-11-15  11SPS                                 NaN
# ...

# %%
CMR.sentinel_ID(tile, "2022-11-01")
# Out:
# 'HLS.S30.T11SPS.2022305T182521.v2.0'

# %%
ID = CMR.sentinel_ID(tile, "2022-11-01")
ID
# Out:
# 'HLS.S30.T11SPS.2022305T182521.v2.0'

# %%
CMR.landsat_ID(tile, "2022-11-01")
# Out:
# 'HLS.L30.T11SPS.2022305T181036.v2.0'

# %%
CMR.sentinel_ID(tile, "2022-11-01")
# Out:
# 'HLS.S30.T11SPS.2022305T182521.v2.0'

# %%
# CMR._URLs[CMR._URLs.ID == ID][["band", "https"]]

# %%
CMR.bands(ID)
# Out:
#       band                                                URL
# 120    VAA  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 125    B11  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 124    B12  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 122  Fmask  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 108    B03  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 109    VZA  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 110    B07  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 111    B02  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 112    B01  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 113    B04  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 114    B06  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 115    B09  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 116    B10  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 117    B08  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# ...

# %%
sentinel_granule = CMR.sentinel(tile, "2022-11-01")
sentinel_granule
# Out:
# [2022-11-11 15:21:05 INFO] searching for Sentinel tile 11SPS on 2022-11-01
# [2022-11-11 15:21:05 INFO] found HLS2 Sentinel directory: /Users/halverso/data/HLS2CMR_testing/HLS2_download/2022.11.01/HLS.S30.T11SPS.2022305T182521.v2.0
# [2022-11-11 15:21:05 INFO] retrieving Sentinel tile 11SPS on 2022-11-01: /Users/halverso/data/HLS2CMR_testing/HLS2_download/2022.11.01/HLS.S30.T11SPS.2022305T182521.v2.0
# [2022-11-11 15:21:05 INFO] downloading: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11SPS.2022305T182521.v2.0/HLS.S30.T11SPS.2022305T182521.v2.0.VAA.tif -> /Users/halverso/data/HLS2CMR_testing/HLS2_download/2022.11.01/HLS.S30.T11SPS.2022305T182521.v2.0/HLS.S30.T11SPS.2022305T182521.v2.0.VAA.tif
# --2022-11-11 15:21:05--  https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11SPS.2022305T182521.v2.0/HLS.S30.T11SPS.2022305T182521.v2.0.VAA.tif
# ...
